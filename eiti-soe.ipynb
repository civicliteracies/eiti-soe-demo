# %% [markdown]
# # Workflow prototype: EITI API CSV dump to Datasette
#
# Our goal is to prototype a workflow that would allow us to go from the provided CSV, which contains 42K lines of company, agency and project data, to a SQLITE database. The database can then be imported into Datasette to generate a web interface enabling data exploration as well as API endpoints.
#
# Only minimal data cleaning will be included in this prototype workflow, as the aim is to demonstrate the validity of the process.

# %% [markdown]
# ## Section 1: Importing the CSV
#
# Loading the CSV and giving it a quick look

# %%
# we first import pandas and sqlite_utils, which allow us to process the CSV data then import it into the database.
# we also import sqlite3 to test some queries on the created database directly from python

import pandas as pd
import sqlite_utils
import sqlite3

# %%
# we load the CSV and display a random sample of the lines for a first visual check

url = "https://raw.githubusercontent.com/clombion/eiti-ose-demo/main/eiti-api-dump.csv"
df = pd.read_csv(url)
df.sample(n=5)
# Out:
# /var/folders/z_/k9wh63yn4bzb0fzdgjkcx6tw0000gn/T/ipykernel_62250/3964467201.py:4: DtypeWarning: Columns (7,11,12,13,14,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
#            id                                              label
# 3398   139623                     State Property Management Fund  \
# 13341  162457                                     Caspi neft JSC
# 40466  183273  Subsoil use special permit No. 2456, dated 27....
# 7535   186458                    Statoil Oil & Gas Mozambique AS
# 6726   158313                                        Concedo ASA
#
#                                                 self     type
# 3398   https://eiti.org/api/v2.0/organisation/139623   agency  \
# 13341  https://eiti.org/api/v2.0/organisation/162457  company
# 40466  https://eiti.org/api/v2.0/organisation/183273  project
# 7535   https://eiti.org/api/v2.0/organisation/186458  company
# 6726   https://eiti.org/api/v2.0/organisation/158313  company
#
#         identification sector  commodities agency_type company_type
# 3398               NaN    NaN          NaN         NaN          NaN  \
# 13341  970 140 000 112    NaN          NaN         NaN          NaN
# 40466              NaN    NaN          NaN         NaN          NaN
# 7535         400155593    NaN          NaN         NaN          NaN
# 6726         988217867    NaN          NaN         NaN          NaN
#
#       stock_exchange_listing  ... project_affiliated_companies_start
# 3398                     NaN  ...                                NaN  \
# 13341                    NaN  ...                                NaN
# 40466                    NaN  ...             Ukrgazvydobuvannya JSC
# 7535                     NaN  ...                                NaN
# 6726                     NaN  ...                                NaN
#
#       project_commodities project_status project_production_volume
# 3398                  NaN            NaN                       NaN  \
# 13341                 NaN            NaN                       NaN
# 40466         Natural gas     Production                55930000.0
# 7535                  NaN            NaN                       NaN
# 6726                  NaN            NaN                       NaN
#
#       project_unit  project_production project_currency summary_data.label
# 3398           NaN                 NaN              NaN    Kyrgyz Republic  \
# 13341          NaN                 NaN              NaN         Kazakhstan
# 40466          Sm3                 NaN              NaN            Ukraine
# 7535           NaN                 NaN              NaN         Mozambique
# 6726           NaN                 NaN              NaN             Norway
#
#        summary_data.iso2 summary_data.year
# 3398                  KG            2004.0
# 13341                 KZ            2014.0
# 40466                 UA            2020.0
# 7535                  MZ            2010.0
# 6726                  NO            2008.0
#
# [5 rows x 22 columns]

# %%
# a second check, this time of the columns and the data types as guessed by pandas

df.dtypes
# Out:
# id                                      int64
# label                                  object
# self                                   object
# type                                   object
# identification                         object
# sector                                 object
# commodities                           float64
# agency_type                            object
# company_type                           object
# stock_exchange_listing                 object
# audited_financial_state                object
# project_legal_agreement                object
# project_affiliated_companies_start     object
# project_commodities                    object
# project_status                         object
# project_production_volume             float64
# project_unit                           object
# project_production                     object
# project_currency                      float64
# summary_data.label                     object
# summary_data.iso2                      object
# summary_data.year                     float64
# dtype: object

# %% [markdown]
# ## Section 2: separating the different types of data
#
# The CSV contains company, agency and project data. To make the final database more efficient, we need to split them into their own table

# %%
# we create three different dataframes, each of them differentiated thanks to the 'type' column.

df_company = df[df['type'] == 'company']
df_agency = df[df['type'] == 'agency']
df_project = df[df['type'] == 'project']

# for each of the created dataframe, we remove any column that is fully blank, allowing us to keep only the relevant columns

df_company = df_company.dropna(how='all', axis=1)
df_agency = df_agency.dropna(how='all', axis=1)
df_project = df_project.dropna(how='all', axis=1)

# %% [markdown]
# Let's visualise the three created datasets while adjusting the datatype of the columns

# %%
# we adjust the datatype of the company dataset to reflect the actual nature of the values

df_company = df_company.astype(str)
df_company['id'] = pd.to_numeric(df_company['id'], errors='coerce') #to_numeric is used because astype(str) fails if there are null values
df_company['summary_data.year'] = pd.to_numeric(df_company['summary_data.year'], errors='coerce')

# we display both the final list of columns and their datatypes

df_company.dtypes
# Out:
# id                           int64
# label                       object
# self                        object
# type                        object
# identification              object
# sector                      object
# company_type                object
# stock_exchange_listing      object
# audited_financial_state     object
# summary_data.label          object
# summary_data.iso2           object
# summary_data.year          float64
# dtype: object

# %%
# we adjust the datatype of the agency dataset to reflect the actual nature of the values

df_agency = df_agency.astype(str)
df_agency['id'] = pd.to_numeric(df_agency['id'], errors='coerce') 
df_agency['summary_data.year'] = pd.to_numeric(df_agency['summary_data.year'], errors='coerce')

# we display both the final list of columns and their datatypes

df_agency.dtypes
# Out:
# id                      int64
# label                  object
# self                   object
# type                   object
# identification         object
# agency_type            object
# summary_data.label     object
# summary_data.iso2      object
# summary_data.year     float64
# dtype: object

# %%
# we adjust the datatype of the project dataset to reflect the actual nature of the values

df_project = df_project.astype(str)
df_project['id'] = pd.to_numeric(df_project['id'], errors='coerce')
df_project['summary_data.year'] = pd.to_numeric(df_project['summary_data.year'], errors='coerce')

# we display both the final list of columns and their datatypes

df_project.dtypes
# Out:
# id                                      int64
# label                                  object
# self                                   object
# type                                   object
# project_legal_agreement                object
# project_affiliated_companies_start     object
# project_commodities                    object
# project_status                         object
# project_production_volume              object
# project_unit                           object
# project_production                     object
# summary_data.label                     object
# summary_data.iso2                      object
# summary_data.year                     float64
# dtype: object

# %% [markdown]
# ## Section 3: creating the database
#
# We now use sqlite_utils to create our database.

# %%
# create the database

db = sqlite_utils.Database('eiti_data.db')

# insert cleaned data into the SQLite database

db["companies"].insert_all(df_company.to_dict('records'))
db["agencies"].insert_all(df_agency.to_dict('records'))
db["projects"].insert_all(df_project.to_dict('records'))
# Out:
# <Table projects (id, label, self, type, project_legal_agreement, project_affiliated_companies_start, project_commodities, project_status, project_production_volume, project_unit, project_production, summary_data.label, summary_data.iso2, summary_data.year)>

# %%
# display schema of the database

for table_name in db.table_names():
    print(f"Schema of {table_name}:")
    print(db[table_name].schema, "\n")
# Out:
# Schema of companies:
# CREATE TABLE [companies] (
#    [id] INTEGER,
#    [label] TEXT,
#    [self] TEXT,
#    [type] TEXT,
#    [identification] TEXT,
#    [sector] TEXT,
#    [company_type] TEXT,
#    [stock_exchange_listing] TEXT,
#    [audited_financial_state] TEXT,
#    [summary_data.label] TEXT,
#    [summary_data.iso2] TEXT,
#    [summary_data.year] FLOAT
# )
#
# Schema of agencies:
# CREATE TABLE [agencies] (
#    [id] INTEGER,
#    [label] TEXT,
#    [self] TEXT,
#    [type] TEXT,
#    [identification] TEXT,
#    [agency_type] TEXT,
#    [summary_data.label] TEXT,
#    [summary_data.iso2] TEXT,
#    [summary_data.year] FLOAT
# )
#
# Schema of projects:
# CREATE TABLE [projects] (
#    [id] INTEGER,
#    [label] TEXT,
#    [self] TEXT,
#    [type] TEXT,
#    [project_legal_agreement] TEXT,
#    [project_affiliated_companies_start] TEXT,
#    [project_commodities] TEXT,
#    [project_status] TEXT,
#    [project_production_volume] TEXT,
#    [project_unit] TEXT,
#    [project_production] TEXT,
#    [summary_data.label] TEXT,
#    [summary_data.iso2] TEXT,
#    [summary_data.year] FLOAT
# )

# %% [markdown]
# ## Section 4
#
# We will now test the creation of foreign keys in the 'projects' table based on company names. That requires a more complex process in order to create a junction table to represent the many to many relationships between companies and projects.

# %%
# Create a table 'project_companies'
db["project_companies"].create({"project_id": str, "company_label": str}, pk=("project_id", "company_label"))
# Out:
# <Table project_companies (project_id, company_label)>

# %%
# Populate the 'project_companies' table
for index, row in df_project.iterrows():
    # Split the affiliated company names
    affiliated_companies = row['project_affiliated_companies_start'].split(',')
    for company_name in affiliated_companies:
        # Clean up the company name
        company_name = company_name.strip()
        # Try to insert the record, update if it already exists (in our case, it will just keep the values the same)
        db["project_companies"].upsert({
            'project_id': row['id'],
            'company_label': company_name  # Ensure no leading/trailing whitespace
        }, pk=('project_id', 'company_label'))  # composite primary key

# %%
# display schema of the database

for table_name in db.table_names():
    print(f"Schema of {table_name}:")
    print(db[table_name].schema, "\n")
# Out:
# Schema of companies:
# CREATE TABLE [companies] (
#    [id] INTEGER,
#    [label] TEXT,
#    [self] TEXT,
#    [type] TEXT,
#    [identification] TEXT,
#    [sector] TEXT,
#    [company_type] TEXT,
#    [stock_exchange_listing] TEXT,
#    [audited_financial_state] TEXT,
#    [summary_data.label] TEXT,
#    [summary_data.iso2] TEXT,
#    [summary_data.year] FLOAT
# )
#
# Schema of agencies:
# CREATE TABLE [agencies] (
#    [id] INTEGER,
#    [label] TEXT,
#    [self] TEXT,
#    [type] TEXT,
#    [identification] TEXT,
#    [agency_type] TEXT,
#    [summary_data.label] TEXT,
#    [summary_data.iso2] TEXT,
#    [summary_data.year] FLOAT
# )
#
# Schema of projects:
# CREATE TABLE [projects] (
#    [id] INTEGER,
#    [label] TEXT,
#    [self] TEXT,
#    [type] TEXT,
#    [project_legal_agreement] TEXT,
#    [project_affiliated_companies_start] TEXT,
#    [project_commodities] TEXT,
#    [project_status] TEXT,
#    [project_production_volume] TEXT,
#    [project_unit] TEXT,
#    [project_production] TEXT,
#    [summary_data.label] TEXT,
#    [summary_data.iso2] TEXT,
#    [summary_data.year] FLOAT
# )
#
# Schema of project_companies:
# CREATE TABLE [project_companies] (
#    [project_id] TEXT,
#    [company_label] TEXT,
#    PRIMARY KEY ([project_id], [company_label])
# )

# %%
# Connect to the SQLite database
conn = sqlite3.connect('eiti_data.db')

# Create a cursor object
c = conn.cursor()

# Define the company name. The query is designed to allow substrings, instead of the exact match of the name, allowing subsidiaries to be included.
company_name = "TOTAL"

# Create the SQL query. 
sql = """
SELECT p.label, pc.company_label
FROM projects p
JOIN project_companies pc ON p.id = pc.project_id
WHERE pc.company_label LIKE ?
"""

# Execute the SQL query
c.execute(sql, ('%' + company_name + '%',))

# Fetch all the records
records = c.fetchall()

# Close the connection
conn.close()

# %%
# test the result by printing a company and its related projects

data = []

for record in records:
    project_name, company_name = record
    data.append({'Company Name': company_name, 'Project Name': project_name})

df_foreign_key_test = pd.DataFrame(data)
df_foreign_key_test.sample(10)
# Out:
#                                Company Name
# 28  TOTALENERGIES E&P UK LIMITED (00811900)  \
# 68                      Total E&P Nederland
# 8                          TOTAL AUSTRAL SA
# 7                          TOTAL AUSTRAL SA
# 47  TOTALENERGIES E&P UK LIMITED (00811900)
# 39  TOTALENERGIES E&P UK LIMITED (00811900)
# 14             TOTSA TOTAL Halfaya Contract
# 83                         Total E&P México
# 43  TOTALENERGIES E&P UK LIMITED (00811900)
# 56                                    Total
#
#                                Project Name
# 28  TOTALENERGIES E&P UK LIMITED (00811900)
# 68                                      L1d
# 8                                     Aries
# 7                                    Carina
# 47  TOTALENERGIES E&P UK LIMITED (00811900)
# 39  TOTALENERGIES E&P UK LIMITED (00811900)
# 14                                  HALFAYA
# 83                   CNH‐R01‐L04‐A1.CS/2016
# 43  TOTALENERGIES E&P UK LIMITED (00811900)
# 56                  CNH-R02-L01-A15.CS/2017

# %% [markdown]
# ## Run datasette using our database
#
# Datasette can be extensively customised, allowing the host to create custom API endpoints based on specific SQL queries. This means that the user stories that the EITI secretariat have defined for their stakeholders can be translated into specific SQL queries which can then be added to the parameters of datasette in order to set them as custom API endpoints.
#
# This is in addition of the user interface which allows non technical users to navigate, filter and export the data without making use of the API. This interface can be customised to match EITI's branding guideline.

# %%
# we start datasette, which opens another page at http://127.0.0.1:8001 

# !datasette serve eiti_data.db
# Out:
# INFO:     Started server process [62308]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8001 (Press CTRL+C to quit)
# INFO:     127.0.0.1:64881 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64881 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64881 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64882 - "GET /eiti_data HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64882 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64882 - "GET /-/static/sql-formatter-2.3.3.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64884 - "GET /-/static/codemirror-5.57.0.min.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64885 - "GET /-/static/codemirror-5.57.0-sql.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64883 - "GET /-/static/codemirror-5.57.0.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64886 - "GET /-/static/cm-resize-1.0.1.min.js HTTP/1.1" 200 OK
# ERROR: conn=<sqlite3.Connection object at 0x1089ce2f0>, sql = 'explain SELECT p.label, pc.company_label\r\nFROM projects p\r\nJOIN project_companies pc ON p.id = pc.project_id\r\nWHERE pc.company_label LIKE ?', params = {}: Binding 1 has no name, but you supplied a dictionary (which has only names).
# ERROR: conn=<sqlite3.Connection object at 0x1089ce2f0>, sql = 'SELECT p.label, pc.company_label\r\nFROM projects p\r\nJOIN project_companies pc ON p.id = pc.project_id\r\nWHERE pc.company_label LIKE ?', params = {}: Binding 1 has no name, but you supplied a dictionary (which has only names).
# INFO:     127.0.0.1:65123 - "GET /eiti_data?sql=SELECT+p.label%2C+pc.company_label%0D%0AFROM+projects+p%0D%0AJOIN+project_companies+pc+ON+p.id+%3D+pc.project_id%0D%0AWHERE+pc.company_label+LIKE+%3F HTTP/1.1" 400 Bad Request
# INFO:     127.0.0.1:65123 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65125 - "GET /-/static/codemirror-5.57.0.min.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65127 - "GET /-/static/cm-resize-1.0.1.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65126 - "GET /-/static/codemirror-5.57.0-sql.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65124 - "GET /-/static/codemirror-5.57.0.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65128 - "GET /-/static/sql-formatter-2.3.3.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65147 - "GET /eiti_data?sql=SELECT+pc.company_label+as+company%2C+p.label+as+project%0D%0AFROM+projects+p%0D%0AJOIN+project_companies+pc+ON+p.id+%3D+pc.project_id%0D%0AWHERE+pc.company_label+LIKE+%27%25TOTAL%25%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65147 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65148 - "GET /-/static/codemirror-5.57.0.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65150 - "GET /-/static/codemirror-5.57.0.min.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65151 - "GET /-/static/codemirror-5.57.0-sql.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65149 - "GET /-/static/sql-formatter-2.3.3.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65152 - "GET /-/static/cm-resize-1.0.1.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65155 - "GET /eiti_data.json?sql=SELECT+pc.company_label+as+company%2C+p.label+as+project%0D%0AFROM+projects+p%0D%0AJOIN+project_companies+pc+ON+p.id+%3D+pc.project_id%0D%0AWHERE+pc.company_label+LIKE+%27%25TOTAL%25%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65156 - "GET /eiti_data HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65156 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65157 - "GET /-/static/sql-formatter-2.3.3.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65159 - "GET /-/static/codemirror-5.57.0.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65160 - "GET /-/static/codemirror-5.57.0-sql.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65158 - "GET /-/static/codemirror-5.57.0.min.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65161 - "GET /-/static/cm-resize-1.0.1.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65164 - "GET /eiti_data/agencies HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65164 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65164 - "GET /-/static/table.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65164 - "GET /eiti_data/agencies.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65174 - "GET /eiti_data HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65174 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65175 - "GET /-/static/sql-formatter-2.3.3.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65176 - "GET /-/static/codemirror-5.57.0.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65178 - "GET /-/static/codemirror-5.57.0-sql.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65177 - "GET /-/static/codemirror-5.57.0.min.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65179 - "GET /-/static/cm-resize-1.0.1.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65176 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65176 - "GET /eiti_data/agencies HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65176 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65175 - "GET /-/static/table.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65176 - "GET /eiti_data/agencies.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65189 - "GET /eiti_data/agencies?_facet=summary_data.year HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65189 - "GET /-/static/table.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65190 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65192 - "GET /eiti_data/agencies?_facet=summary_data.year&summary_data.year=2017.0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65192 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65193 - "GET /-/static/table.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65201 - "GET /eiti_data/agencies?_facet=summary_data.year HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65201 - "GET /-/static/table.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65202 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65216 - "GET /eiti_data HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65216 - "GET /-/static/sql-formatter-2.3.3.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65217 - "GET /-/static/codemirror-5.57.0.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65218 - "GET /-/static/codemirror-5.57.0-sql.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65219 - "GET /-/static/cm-resize-1.0.1.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65221 - "GET /-/static/codemirror-5.57.0.min.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65220 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65225 - "GET /eiti_data?sql=SELECT+pc.company_label+as+company%2C+p.label+as+project%0D%0AFROM+projects+p%0D%0AJOIN+project_companies+pc+ON+p.id+%3D+pc.project_id%0D%0AWHERE+pc.company_label+LIKE+%27%25TOTAL%25%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65225 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65226 - "GET /-/static/sql-formatter-2.3.3.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65228 - "GET /-/static/codemirror-5.57.0.min.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65229 - "GET /-/static/codemirror-5.57.0-sql.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65227 - "GET /-/static/codemirror-5.57.0.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65230 - "GET /-/static/cm-resize-1.0.1.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65227 - "GET /eiti_data.json?sql=SELECT+pc.company_label+as+company%2C+p.label+as+project%0D%0AFROM+projects+p%0D%0AJOIN+project_companies+pc+ON+p.id+%3D+pc.project_id%0D%0AWHERE+pc.company_label+LIKE+%27%25TOTAL%25%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65290 - "GET /eiti_data.json?sql=SELECT+pc.company_label+as+company%2C+p.label+as+project%0D%0AFROM+projects+p%0D%0AJOIN+project_companies+pc+ON+p.id+%3D+pc.project_id%0D%0AWHERE+pc.company_label+LIKE+%27%25TOTAL%25%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65486 - "GET /eiti_data?sql=SELECT+pc.company_label+as+company%2C+p.label+as+project%0D%0AFROM+projects+p%0D%0AJOIN+project_companies+pc+ON+p.id+%3D+pc.project_id%0D%0AWHERE+pc.company_label+LIKE+%27%25TOTAL%25%27%0D%0A HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65486 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65487 - "GET /-/static/codemirror-5.57.0.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65489 - "GET /-/static/codemirror-5.57.0-sql.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65488 - "GET /-/static/codemirror-5.57.0.min.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65490 - "GET /-/static/cm-resize-1.0.1.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65491 - "GET /-/static/sql-formatter-2.3.3.min.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65487 - "GET /eiti_data.json?sql=SELECT+pc.company_label+as+company%2C+p.label+as+project%0D%0AFROM+projects+p%0D%0AJOIN+project_companies+pc+ON+p.id+%3D+pc.project_id%0D%0AWHERE+pc.company_label+LIKE+%27%25TOTAL%25%27%0D%0A HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65500 - "GET /eiti_data.json?sql=SELECT+pc.company_label+as+company%2C+p.label+as+project%0D%0AFROM+projects+p%0D%0AJOIN+project_companies+pc+ON+p.id+%3D+pc.project_id%0D%0AWHERE+pc.company_label+LIKE+%27%25TOTAL%25%27%0D%0A HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65503 - "GET /eiti_data.json?sql=SELECT+pc.company_label+as+company%2C+p.label+as+project%0D%0AFROM+projects+p%0D%0AJOIN+project_companies+pc+ON+p.id+%3D+pc.project_id%0D%0AWHERE+pc.company_label+LIKE+%27%25TOTAL%25%27%0D%0A HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49628 - "GET /eiti_data/projects HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49628 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49629 - "GET /-/static/table.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49630 - "GET /eiti_data/companies HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49630 - "GET /-/static/table.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49631 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49640 - "GET /eiti_data/companies?_filter_column=label&_filter_op=contains&_filter_value=total&_sort=rowid HTTP/1.1" 302 Found
# INFO:     127.0.0.1:49640 - "GET /eiti_data/companies?_sort=rowid&label__contains=total HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49640 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49641 - "GET /-/static/table.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49645 - "GET /eiti_data/companies.json?_sort=rowid&label__contains=total&_shape=array HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49646 - "GET /eiti_data/companies.json?_sort=rowid&label__contains=total&_shape=array&_nl=on HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49652 - "GET /eiti_data/projects HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49652 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49653 - "GET /-/static/table.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49657 - "GET /eiti_data/projects?_filter_column=project_affiliated_companies_start&_filter_op=contains&_filter_value=total&_sort=rowid HTTP/1.1" 302 Found
# INFO:     127.0.0.1:49657 - "GET /eiti_data/projects?_sort=rowid&project_affiliated_companies_start__contains=total HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49657 - "GET /-/static/table.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49658 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49664 - "GET /eiti_data/project_companies HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49664 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49664 - "GET /-/static/table.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49664 - "GET /eiti_data/project_companies/135956%2CNot%2Breported HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49664 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49667 - "GET /eiti_data/project_companies?_filter_column=company_label&_filter_op=contains&_filter_value=total&_sort= HTTP/1.1" 302 Found
# INFO:     127.0.0.1:49667 - "GET /eiti_data/project_companies?company_label__contains=total HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49667 - "GET /-/static/table.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49668 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49667 - "GET /eiti_data/project_companies/138008%2CTotal%2BE~26P%2BSenegal HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49667 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49667 - "GET /eiti_data/project_companies/138285%2CTotal%2BE~26P HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49667 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49671 - "GET /eiti_data/project_companies/145255%2CPetrochina%2B~28~2545~29%2B~2F%2BPetronas%2B~28~2522~2E5~29%2B~2F%2BTOTAL%2B~28~2522~2E5~29%2B~2F%2BBasra%2BOil%2BCompany%2B~E2~80~93%2BBOC%2B~28~2510~29 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49671 - "GET /-/static/app.css?d59929 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49673 - "GET /eiti_data/project_companies.json?company_label__contains=total HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49684 - "GET /eiti_data/project_companies.json?company_label__contains=total?labels=on HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49690 - "GET /eiti_data/project_companies.json?company_label__contains=total HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49693 - "GET /eiti_data/project_companies.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49699 - "GET /eiti_data/project_companies.json?labels=on HTTP/1.1" 200 OK
# ^C
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [62308]
